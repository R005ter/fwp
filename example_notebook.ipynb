# %% [markdown]
# # Example Databricks Notebook
#
# This is a sample notebook that can be edited locally in Cursor and synced to Databricks.
#
# ## Usage
#
# 1. Edit this notebook in Cursor
# 2. Run: `python databricks_sync.py sync example_notebook.ipynb`
# 3. Check results in Databricks or via CLI

# %%
# Example: Simple data processing
import pandas as pd
import numpy as np

# Create sample data
data = pd.DataFrame({
    'x': np.random.randn(100),
    'y': np.random.randn(100)
})

print(f"Data shape: {data.shape}")
print(data.head())

# %%
# Example: Use Databricks utilities
# dbutils is available in Databricks runtime

# List files in DBFS
# files = dbutils.fs.ls("/")
# for file in files:
#     print(file.name)
